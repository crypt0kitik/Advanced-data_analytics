# %% [markdown]
# # In this notebook I paste screenshots and insights

# %% [markdown]
# 01 -  Sampling technique (oversampling): could not instal the imblearn module
#
# ![image.png](attachment:image.png)
