# %% [markdown]
# # In this notebook I paste screenshots and insights

# %% [markdown]
# # 01 -  Sampling technique (oversampling)
#
# before
# ![image.png](attachment:image.png)
#
# after
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 02 - Data synthetization (CTGAN)
#
# we increased data in 10 times but we were able to keep our good distibution
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 02 - Data synthetization (SDV)

# %% [markdown]
# # 03 - Noise Management (MAD)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 03 - Noise Management (RANSAC)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 04 - Overlap Management (Autoencoders)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # 05 - Outlier Management (IQR + Isolation Forest)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
