# %% [markdown]
# # Report

# %% [markdown]
# In the report there are screenshots combined with text.
#
# 1. The Classification dataset has been into these tests:
# *01 - Autoviz: have an error. Needed your advice*
# *02 - Dataprep: have an error. Needed your advice. It was succefully employed in another porject*
# 03 - Lime
# 04 - Phik-matrix
# 05 - Sweetwiz_report
# 06 - Ydata_report
#
# 2. The Regression dataset has been into these tests:
# *01 - Autoviz: have an error. Needed your advice*
# 02 - Dataprep
# 03 - Lime
# 04 - Phik-matrix
# 05 - Sweetwiz_report
# 06 - Ydata_report
# 07 - Mad_test
# 08 - Seaborn_polynomial_test
#
# 3. The time-series dataset
# *01 - Prophet: in doubts that it is correct*

# %% [markdown]
# # 1. Classification dataset

# %% [markdown]
# 01 - Autoviz
# ![alt text](image.png)

# %% [markdown]
# 02 - Dataprep
#
# ![alt text](image-1.png)

# %% [markdown]
# 03 - Lime
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 04 - Phik-matrix
#
# ![alt text](image-3.png)
#
# ![alt text](image-4.png)

# %% [markdown]
# 05 - Sweetwiz_report
#
# ![image.png](attachment:image.png)
#
# ![alt text](image-7.png)

# %% [markdown]
# 06 - Ydata_report
#
# ![image.png](attachment:image.png)
#
# ![alt text](image-9.png)

# %% [markdown]
# # 2. Regression dataset

# %% [markdown]
# 01 - Autoviz
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 02 - Dataprep
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 03 - Lime
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 04 - Phik-matrix
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 05 - Sweetwiz_report
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 06 - Ydata_report
#
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 07 - Mad_test
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 08 - Seaborn_polynomial_test
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # 3. The time-series dataset

# %% [markdown]
# 01 - Prophet
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
