# %% [markdown]
# # Report

# %% [markdown]
# In the report there are screenshots combined with text.
#
# 1. The Classification dataset has been into these tests:
# 01 - Autoviz
# 02 - Dataprep
# 03 - Lime
# 04 - Phik-matrix
# 05 - Sweetwiz_report
# 06 - Ydata_report
#
# 2. The Logistic dataset has been into these tests:
# 01 - Autoviz
# 02 - Dataprep
# 03 - Lime
# 04 - Phik-matrix
# 05 - Sweetwiz_report
# 06 - Ydata_report
# 07 - Mad_test
# 08 - Seaborn_polynomial_test
#
# 3. The time-series dataset

# %% [markdown]
# # 1. Classification dataset

# %% [markdown]
# 01 - Autoviz

# %% [markdown]
# 03 - Lime
#
# ![image.png](attachment:image.png)
