# %%
# pip install autoviz jinja2==3.1.2 jupyter_bokeh

from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
report = AV.AutoViz("imdb_movie_data_2023.csv", chart_format="bokeh", depVar="Rating") 

# I have an error
# ValueError: expected a non-empty sequence of strings, got typing.Literal['replace', 'append', 'intersect', 'subtract', 'xor'] or toggle


# I tried:
# pip install --upgrade holoviews bokeh
# pip install holoviews==1.14.5
# pip install --upgrade autoviz
# pip install bokeh==2.3.3
# but it did not help
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (1950, 11)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  3
# ...

# %%
# insights:

# The scatter plot shows a positive correlation between 
# the number of votes and the movie rating
# Higher-rated movies tend to have more votes, 
# suggesting popular or critically acclaimed 
# movies attract more attention,
# which is quite obvious

# heat map:
# Meta Score is also moderately correlated with Rating (0.71), 
# implying a connection between professional 
# critic scores and user ratings.

# something interesting about Time Series Plot:
# Time Series Plot:
# Numeric variables plotted over time (e.g., Year vs. Votes) 
# show a growing trend in Votes for newer movies
# This likely reflects the increased accessibility 
# of movies and voting platforms in recent years.

# one more interesting insights:
# Categorical Aggregation (PG Rating):
# The bar chart indicates the average of numeric variables (like Votes) 
# grouped by PG Rating categories. Movies with an "18+" 
# rating attract the highest average votes, which might correlate 
# with their target demographic or the nature of the content.
