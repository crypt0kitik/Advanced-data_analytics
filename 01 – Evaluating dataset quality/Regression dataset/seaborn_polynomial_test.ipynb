# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Numeric data (last year work).csv")

# %%
df.head()
# Out:
#    Rating    Votes  Meta Score  Year  Duration  Action  Adventure  Animation  \
# 0     6.5  90000.0        67.0  2023       138       0          0          0
# 1     7.4  24000.0        66.0  2023       116       0          1          0
# 2     7.0  21000.0        85.0  2023       117       0          0          0
# 3     7.1  56000.0        54.0  2023       157       1          1          0
# 4     6.6  66000.0        64.0  2023       158       1          1          0
#
#    Biography  Comedy  ...  PG Rating_NC-17  PG Rating_PG  PG Rating_PG-13  \
# 0          0       0  ...                0             0                0
# 1          0       1  ...                0             1                0
# 2          0       1  ...                0             0                0
# 3          0       0  ...                0             0                1
# 4          1       0  ...                0             0                0
#
# ...

# %%
print(df.dtypes)
# Out:
# Rating                float64
# Votes                 float64
# Meta Score            float64
# Year                    int64
# Duration                int64
# Action                  int64
# Adventure               int64
# Animation               int64
# Biography               int64
# Comedy                  int64
# Crime                   int64
# Documentary             int64
# Drama                   int64
# Family                  int64
# Fantasy                 int64
# History                 int64
# Horror                  int64
# Music                   int64
# Musical                 int64
# Mystery                 int64
# Romance                 int64
# Sci-Fi                  int64
# Sport                   int64
# Thriller                int64
# War                     int64
# Western                 int64
# PG Rating_13+           int64
# PG Rating_16+           int64
# PG Rating_18+           int64
# PG Rating_Approved      int64
# PG Rating_G             int64
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Numeric data (last year work).csv")

# init plot
fig, axes = plt.subplots(1, 4, figsize=(20, 4))

# compared variables
var1 = "Rating"
var2 = "Year"

# title
fig.suptitle(f'Polynomial regression plot - ({var1}, {var2}, 2-5 degrees)')

# create plots
sns.regplot(ax=axes[0], x=var1, y=var2, data=df[[var1, var2]], order=2)
sns.regplot(ax=axes[1], x=var1, y=var2, data=df[[var1, var2]], order=3)
sns.regplot(ax=axes[2], x=var1, y=var2, data=df[[var1, var2]], order=4)
sns.regplot(ax=axes[3], x=var1, y=var2, data=df[[var1, var2]], order=5)
# Out:
# <Axes: xlabel='Rating', ylabel='Year'>

# %%
# In these plots, I have order 2 to 5 Polynomial Regressions,
# which means that I am plotting different polynomial fits 
# (quadratic, cubic, quartic, and quintic) to see how the Rating relates to the Year.

# Insights:
# In the 1st picture,
# the plot shows a slight downward trend, indicating that 
# movies with higher ratings are generally older. The relationship 
# is not perfectly linear but has a curve, suggesting that ratings 
# might have slightly changed over time.
# The other plots show the same general trend.

# There's no positive correlation between Rating and Year.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Numeric data (last year work).csv")

# init plot
fig, axes = plt.subplots(1, 4, figsize=(20, 4))

# compared variables
var1 = "Rating"
var2 = "Meta Score"

# title
fig.suptitle(f'Polynomial regression plot - ({var1}, {var2}, 2-5 degrees)')

# create plots
sns.regplot(ax=axes[0], x=var1, y=var2, data=df[[var1, var2]], order=2)
sns.regplot(ax=axes[1], x=var1, y=var2, data=df[[var1, var2]], order=3)
sns.regplot(ax=axes[2], x=var1, y=var2, data=df[[var1, var2]], order=4)
sns.regplot(ax=axes[3], x=var1, y=var2, data=df[[var1, var2]], order=5)
# Out:
# <Axes: xlabel='Rating', ylabel='Meta Score'>

# %%
# Insights:

# I have chosen variables that should definitely 
# have a high positive correlation.
# Let's see if we can observe this on the plots.

# The regression line shows a general upward trend, 
# indicating that as the Rating increases, 
# the Meta Score also increases.

# As the polynomial degree increases, 
# the curves become slightly more complex, 
# but the general upward trend remains consistent.

# The plots show a positive correlation between Rating and Meta Score.
# Proven! :)

# However, there is one interesting point:
# Most of the data points are tightly clustered 
# between a rating range of 6.0 to 8.0 and 
# a Meta Score range of 60 to 80.
# This means the majority of the movies in the dataset 
# have scores that fall within this range.
