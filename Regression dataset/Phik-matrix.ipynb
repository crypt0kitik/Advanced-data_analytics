# %%
# pip install phik
import phik
import pandas as pd

# load data
df = pd.read_csv("imdb_movie_data_2023.csv")

# compute phik-matrix values
phik_matrix = df.phik_matrix()

phik_matrix
# Out:
# interval columns not set, guessing: ['Unnamed: 0', 'Rating', 'Votes', 'Meta Score', 'Year']
# c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\phik\data_quality.py:59: UserWarning: The number of unique values of variable Cast is large: 1823. Are you sure this is not an interval variable? Analysis for pairs of variables including Cast can be slow.
#   warnings.warn(
# c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\phik\data_quality.py:59: UserWarning: The number of unique values of variable Moive Name is large: 1914. Are you sure this is not an interval variable? Analysis for pairs of variables including Moive Name can be slow.
#   warnings.warn(
#             Unnamed: 0  Moive Name    Rating     Votes  Meta Score     Genre  \
# Unnamed: 0    1.000000    0.714962  0.296854  0.368084    0.115987  0.228545
# Moive Name    0.714962    1.000000  0.000000  0.995876    0.000000  0.987719
# ...

# %%
# it took 5.53 minutes to generate this table
#
