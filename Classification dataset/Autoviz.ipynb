# %%
# pip install autoviz jinja2==3.1.2 jupyter_bokeh

from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
report = AV.AutoViz("bank.csv", chart_format="bokeh", depVar="deposit") 

# I tried:
# pip install --upgrade holoviews bokeh
# pip install holoviews==1.14.5
# pip install --upgrade autoviz
# pip install bokeh==2.3.3
# pip install panel==0.11.3
# pip install --upgrade panel
# pip install jinja2==2.11.3
# but it did not help
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 # pip install autoviz jinja2==3.1.2 jupyter_bokeh
# ----> 3 from autoviz.AutoViz_Class import AutoViz_Class
#       4 AV = AutoViz_Class()
#       5 report = AV.AutoViz("bank.csv", chart_format="bokeh", depVar="deposit")
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\autoviz\__init__.py:3
#       1 name = "autoviz"
#       2 from .__version__ import __version__, __holo_version__
# ----> 3 from .AutoViz_Class import AutoViz_Class
#       4 from .AutoViz_Class import data_cleaning_suggestions
#       5 from .AutoViz_Class import FixDQ
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\autoviz\AutoViz_Class.py:29
#      27 from pandas_dq import Fix_DQ, dq_report
#      28 ##########################################################################################
# ---> 29 from autoviz.AutoViz_Holo import AutoViz_Holo
#      30 from autoviz.AutoViz_Utils import draw_pivot_tables, draw_scatters
#      31 from autoviz.AutoViz_Utils import draw_pair_scatters, draw_barplots, draw_heatmap
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\autoviz\AutoViz_Holo.py:1
# ----> 1 from holoviews.ipython import display
#       3 from autoviz.AutoViz_Utils import classify_print_vars, find_remove_duplicates
#       4 import numpy as np
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\holoviews\__init__.py:123
#     119 warnings.filterwarnings("ignore",
#     120                         message="elementwise comparison failed; returning scalar instead")
#     122 if "IPython" in sys.modules:
# --> 123     from .ipython import notebook_extension
#     124     extension = notebook_extension
#     125 else:
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\holoviews\ipython\__init__.py:15
#      13 from ..core.tree import AttrTree
#      14 from ..element.comparison import ComparisonTestCase
# ---> 15 from ..plotting.renderer import Renderer
#      16 from ..util import extension
#      17 from .display_hooks import display, png_display, pprint_display, svg_display
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\holoviews\plotting\__init__.py:12
#      10 from ..element.sankey import Sankey, _layout_sankey
#      11 from ..operation.stats import bivariate_kde, univariate_kde
# ---> 12 from .plot import Plot
#      13 from .renderer import HTML_TAGS, Renderer  # noqa (API import)
#      14 from .util import apply_nodata, flatten_stack, list_cmaps  # noqa (API import)
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\holoviews\plotting\plot.py:15
#      13 import numpy as np
#      14 import param
# ---> 15 from panel.config import config
#      16 from panel.io.document import unlocked
#      17 from panel.io.notebook import push
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\panel\__init__.py:1
# ----> 1 """
#       2 Panel is a high level app and dashboarding framework
#       3 ====================================================
#       4
#       5 Panel is an open-source Python library that lets you create custom
#       6 interactive web apps and dashboards by connecting user-defined widgets
#       7 to plots, images, tables, or text.
#       8
#       9 Panel works with the tools you know and ❤️.
#      10
#      11 Check out https://panel.holoviz.org/
#      12
#      13 .. figure:: https://user-images.githubusercontent.com/42288570/152672367-6c239073-0ea0-4a2b-a4c0-817e8090e877.gif
#      14    :alt: Panel Dashboard
#      15
#      16    Panel Dashboard
#      17
#      18 How to develop a Panel app in 3 simple steps
#      19 --------------------------------------------
#      20
#      21 - Write the app
#      22
#      23 >>> import panel as pn
#      24 >>> pn.extension(sizing_mode="stretch_width", template="fast")
#      25 >>> pn.state.template.param.update(title="My Data App")
#      26 >>> pn.panel(some_python_object).servable()
#      27
#      28 - Run your app
#      29
#      30 $ panel serve my_script.py --autoreload --show
#      31
#      32 or
#      33
#      34 $ panel serve my_notebook.ipynb --autoreload --show
#      35
#      36 The app will be available in your browser!
#      37
#      38 - Change your code and save it
#      39
#      40 The app will reload with your changes!
#      41
#      42 You can also add automatic reload to jupyterlab. Check out
#      43 https://blog.holoviz.org/panel_0.12.0.html#JupyterLab-previews
#      44
#      45 To learn more about Panel check out
#      46 https://panel.holoviz.org/getting_started/index.html
#      47 """
#      48 from param import rx
#      50 from . import layout  # noqa
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\panel\layout\__init__.py:1
# ----> 1 """
#       2 Layout
#       3 ======
#       4
#       5 Layouts can layout your python objects and panel components.
#       6
#       7 Most layouts behave as the Python containers you already know. For example
#       8 `Column` and `Row` behaves as lists. I.e. they have a list-like API with
#       9 methods to `append`, `extend`, `clear`, `insert`, `pop`, `remove` and
#      10 `__setitem__`, which make it possible to interactively update and modify them.
#      11
#      12 Check out the Panel gallery of layouts
#      13 https://panel.holoviz.org/reference/index.html#layouts for inspiration.
#      14
#      15 How to use layouts in 2 simple steps
#      16 ------------------------------------
#      17
#      18 1. Define your Python objects
#      19
#      20 >>> some_python_object = ...
#      21 >>> some_widget = pn.widgets...
#      22 >>> some_pane = pn.pane...
#      23
#      24 2. Define your layouts
#      25
#      26 >>> pn.Column(some_python_object, some_widget, some_pane)
#      27
#      28 For more detail see the Getting Started Guide
#      29 https://panel.holoviz.org/getting_started/index.html
#      30 """
#      31 from .accordion import Accordion  # noqa
#      32 from .base import (  # noqa
#      33     Column, ListLike, ListPanel, Panel, Row, WidgetBox,
#      34 )
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\panel\layout\accordion.py:5
#       1 from __future__ import annotations
#       3 from typing import (
#       4     TYPE_CHECKING, Callable, ClassVar, Mapping,
# ----> 5 )
#       7 import param
#       9 from bokeh.models import Column as BkColumn, CustomJS
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\panel\layout\base.py:13
#      11 from ..io.model import hold
#      12 from ..io.state import state
# ---> 13 from ..reactive import Reactive
#      14 from ..util import param_name, param_reprs
#      16 _row = namedtuple("row", ["children"])
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\panel\reactive.py:20
#      17 from functools import lru_cache, partial
#      18 from pprint import pformat
#      19 from typing import (
# ---> 20     TYPE_CHECKING, Any, Callable, ClassVar, Mapping, Optional, Union,
#      21 )
#      23 import numpy as np
#      24 import param
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\panel\config.py:20
#      15 import param
#      17 from pyviz_comms import (JupyterCommManager as _JupyterCommManager,
#      18                          extension as _pyviz_extension)
# ---> 20 from .io.notebook import load_notebook
#      21 from .io.state import state
#      23 __version__ = str(param.version.Version(
#      24     fpath=__file__, archive_commit="$Format:%h$", reponame="panel"))
#
# File c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\panel\io\__init__.py:9
#       6 import logging
#       7 import sys
# ----> 9 from ..config import config
#      11 from .callbacks import PeriodicCallback # noqa
#      12 from .embed import embed_state # noqa
#
# ImportError: cannot import name 'config' from partially initialized module 'panel.config' (most likely due to a circular import) (c:\Users\e1003118\OneDrive - Enersense\Tiedostot\Advanced-data_analytics\.venv\lib\site-packages\panel\config.py)
