# %%
# pip install phik
import phik
import pandas as pd

# load data
df = pd.read_csv("bank.csv")

# compute phik-matrix values
phik_matrix = df.phik_matrix()

phik_matrix
# Out:
# interval columns not set, guessing: ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']
#                 age       job   marital  education   default   balance  \
# age        1.000000  0.575361  0.520057   0.274872  0.033014  0.247859
# job        0.575361  1.000000  0.460727   0.774534  0.054537  0.111781
# marital    0.520057  0.460727  1.000000   0.131382  0.008694  0.056911
# education  0.274872  0.774534  0.131382   1.000000  0.006493  0.101066
# default    0.033014  0.054537  0.008694   0.006493  1.000000  0.072945
# balance    0.247859  0.111781  0.056911   0.101066  0.072945  1.000000
# housing    0.312015  0.397558  0.025214   0.205996  0.006534  0.119995
# loan       0.110585  0.173822  0.039039   0.138839  0.117145  0.131235
# contact    0.323367  0.371762  0.190989   0.137614  0.026369  0.118336
# day        0.105168  0.101742  0.044444   0.061223  0.021149  0.079002
# month      0.200722  0.338447  0.140670   0.209072  0.076029  0.131239
# ...

# %%
#
